# %% [markdown]
# #### Importacion de Datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head(5)
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# # 1. Análisis de facturación

# %%
Ingresos_tienda1=tienda['Precio'].sum()
Ingresos_tienda2=tienda2['Precio'].sum()
Ingresos_tienda3=tienda3['Precio'].sum()
Ingresos_tienda4=tienda4['Precio'].sum()
print(f'Ingresos tienda 1: S/ {Ingresos_tienda1:,.2f}')
print(f'Ingresos tienda 2: S/ {Ingresos_tienda2:,.2f}')
print(f'Ingresos tienda 3: S/ {Ingresos_tienda3:,.2f}')
print(f'Ingresos tienda 4: S/ {Ingresos_tienda4:,.2f}')
# Out:
# Ingresos tienda 1: S/ 1,150,880,400.00
# Ingresos tienda 2: S/ 1,116,343,500.00
# Ingresos tienda 3: S/ 1,098,019,600.00
# Ingresos tienda 4: S/ 1,038,375,700.00

# %%
##### Generando graficos estadisticos
import matplotlib.pyplot as plt
tiendas = ['tienda1', 'tienda2', 'tienda3', 'tienda4']
ingresos= [Ingresos_tienda1, Ingresos_tienda2, Ingresos_tienda3, Ingresos_tienda4]
barras=plt.bar(tiendas, ingresos)
## titulos
plt.title('Ingresos por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Ingresos')
# Out:
# Text(0, 0.5, 'Ingresos')

# %% [markdown]
# # 2. Ventas por categoría

# %%
venta_tienda1=tienda['Categoría del Producto'].value_counts()
venta_tienda2=tienda2['Categoría del Producto'].value_counts()
venta_tienda3=tienda3['Categoría del Producto'].value_counts()
venta_tienda4=tienda4['Categoría del Producto'].value_counts()

ventas_categoria=pd.DataFrame({'tienda1':venta_tienda1, 'tienda2':venta_tienda2, 'tienda3':venta_tienda3, 'tienda4':venta_tienda4})
ventas_categoria
# Out:
#                          tienda1  tienda2  tienda3  tienda4
# Categoría del Producto
# Artículos para el hogar      171      181      177      201
# Deportes y diversión         284      275      277      277
# Electrodomésticos            312      305      278      254
# Electrónicos                 448      422      451      451
# Instrumentos musicales       182      224      177      170
# Juguetes                     324      313      315      338
# Libros                       173      197      185      187
# Muebles                      465      442      499      480

# %%
#grafico=ventas_categoria.plot.bar(stacked=True)
grafico=ventas_categoria.plot(kind='bar',figsize=(10, 5), color=['#E52020', '#FBA518', '#F9CB43', '#A89C29'], alpha=0.7)
plt.title('Ventas por categoria')
plt.xlabel('Categorias')
plt.ylabel('Ventas')
plt.legend(title='Tiendas')

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio_tienda1=tienda['Calificación'].mean()
promedio_tienda2=tienda2['Calificación'].mean()
promedio_tienda3=tienda3['Calificación'].mean()
promedio_tienda4=tienda4['Calificación'].mean()
print(f'Calificación Promedio de la tienda 1: {promedio_tienda1:.2f}')
print(f'Calificación Promedio de la tienda 2: {promedio_tienda2:.2f}')
print(f'Calificación Promedio de la tienda 3: {promedio_tienda3:.2f}')
print(f'Calificación Promedio de la tienda 4: {promedio_tienda4:.2f}')
# Out:
# Calificación Promedio de la tienda 1: 3.98
# Calificación Promedio de la tienda 2: 4.04
# Calificación Promedio de la tienda 3: 4.05
# Calificación Promedio de la tienda 4: 4.00

# %%
#plt.scatter(tiendas, [promedio_tienda1, promedio_tienda2, promedio_tienda3, promedio_tienda4], color='blue')
plt.plot(tiendas, [promedio_tienda1, promedio_tienda2, promedio_tienda3, promedio_tienda4],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Calificación promedio por tienda')
# Out:
# Text(0.5, 1.0, 'Calificación promedio por tienda')

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ### Productos mas y menos vendidos Tienda 1

# %%
## top 5 productos mas vendidos tienda 1
productos_mas_vendidos=tienda['Producto'].value_counts().sort_values(ascending=False).head(5)
productos_mas_vendidos_df = productos_mas_vendidos.reset_index()
productos_mas_vendidos_df.columns = ['Producto', 'Cantidad']
productos_mas_vendidos_df
# Out:
#            Producto  Cantidad
# 0        Microondas        60
# 1     TV LED UHD 4K        60
# 2           Armario        60
# 3  Secadora de ropa        58
# 4     Mesa de noche        56

# %%
plt.plot(productos_mas_vendidos_df['Producto'], productos_mas_vendidos_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos mas vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Microondas'),
#   Text(1, 0, 'TV LED UHD 4K'),
#   Text(2, 0, 'Armario'),
#   Text(3, 0, 'Secadora de ropa'),
#   Text(4, 0, 'Mesa de noche')])

# %%
## top 5 productos menos vendidos
productos_menos_vendidos=tienda['Producto'].value_counts().sort_values(ascending=True).head(5)
productos_menos_vendidos
productos_menos_vendidos_df = productos_menos_vendidos.reset_index()
productos_menos_vendidos_df.columns = ['Producto', 'Cantidad']
productos_menos_vendidos_df
# Out:
#                     Producto  Cantidad
# 0  Auriculares con micrófono        33
# 1               Celular ABXY        33
# 2            Olla de presión        35
# 3                  Pandereta        36
# 4                    Mochila        39

# %%
plt.plot(productos_menos_vendidos_df['Producto'], productos_menos_vendidos_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos menos vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Auriculares con micrófono'),
#   Text(1, 0, 'Celular ABXY'),
#   Text(2, 0, 'Olla de presión'),
#   Text(3, 0, 'Pandereta'),
#   Text(4, 0, 'Mochila')])

# %% [markdown]
# ### Productos mas y menos vendidos Tienda 2

# %%
## top 5 productos mas vendidos tienda 2
productos_mas_vendidos2=tienda2['Producto'].value_counts().sort_values(ascending=False).head(5)
productos_mas_vendidos2_df = productos_mas_vendidos2.reset_index()
productos_mas_vendidos2_df.columns = ['Producto', 'Cantidad']
productos_mas_vendidos2_df
# Out:
#                     Producto  Cantidad
# 0  Iniciando en programación        65
# 1                 Microondas        62
# 2                    Batería        61
# 3          Guitarra acústica        58
# 4                  Pandereta        58

# %%
plt.plot(productos_mas_vendidos2_df['Producto'], productos_mas_vendidos2_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos mas vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Iniciando en programación'),
#   Text(1, 0, 'Microondas'),
#   Text(2, 0, 'Batería'),
#   Text(3, 0, 'Guitarra acústica'),
#   Text(4, 0, 'Pandereta')])

# %%
## top 5 productos menos vendidos
productos_menos_vendidos2=tienda2['Producto'].value_counts().sort_values(ascending=True).head(5)
productos_menos_vendidos2
productos_menos_vendidos2_df = productos_menos_vendidos2.reset_index()
productos_menos_vendidos2_df.columns = ['Producto', 'Cantidad']
productos_menos_vendidos2_df
# Out:
#           Producto  Cantidad
# 0    Juego de mesa        32
# 1  Mesa de comedor        34
# 2        Impresora        34
# 3           Sillón        35
# 4      Auriculares        37

# %%
plt.plot(productos_menos_vendidos2_df['Producto'], productos_menos_vendidos2_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos menos vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Juego de mesa'),
#   Text(1, 0, 'Mesa de comedor'),
#   Text(2, 0, 'Impresora'),
#   Text(3, 0, 'Sillón'),
#   Text(4, 0, 'Auriculares')])

# %% [markdown]
# ### Productos mas y menos vendidos Tienda 3

# %%
## top 5 productos mas vendidos tienda 3
productos_mas_vendidos3=tienda3['Producto'].value_counts().sort_values(ascending=False).head(5)
productos_mas_vendidos3_df = productos_mas_vendidos3.reset_index()
productos_mas_vendidos3_df.columns = ['Producto', 'Cantidad']
productos_mas_vendidos3_df
# Out:
#           Producto  Cantidad
# 0    Kit de bancas        57
# 1  Mesa de comedor        56
# 2        Cama king        56
# 3     Set de ollas        55
# 4    Mesa de noche        55

# %%
plt.plot(productos_mas_vendidos3_df['Producto'], productos_mas_vendidos3_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos mas vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Kit de bancas'),
#   Text(1, 0, 'Mesa de comedor'),
#   Text(2, 0, 'Cama king'),
#   Text(3, 0, 'Set de ollas'),
#   Text(4, 0, 'Mesa de noche')])

# %%
## top 5 productos menos vendidos
productos_menos_vendidos3=tienda3['Producto'].value_counts().sort_values(ascending=True).head(5)
productos_menos_vendidos3
productos_menos_vendidos3_df = productos_menos_vendidos3.reset_index()
productos_menos_vendidos3_df.columns = ['Producto', 'Cantidad']
productos_menos_vendidos3_df
# Out:
#                   Producto  Cantidad
# 0  Bloques de construcción        35
# 1               Microondas        36
# 2             Set de vasos        36
# 3                  Mochila        36
# 4             Vaso térmico        38

# %%
plt.plot(productos_menos_vendidos3_df['Producto'], productos_menos_vendidos3_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos menos vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Bloques de construcción'),
#   Text(1, 0, 'Microondas'),
#   Text(2, 0, 'Set de vasos'),
#   Text(3, 0, 'Mochila'),
#   Text(4, 0, 'Vaso térmico')])

# %% [markdown]
# ### Productos mas y menos vendidos Tienda 4

# %%
productos_mas_vendidos4=tienda4['Producto'].value_counts().sort_values(ascending=False).head(5)
productos_mas_vendidos4_df = productos_mas_vendidos4.reset_index()
productos_mas_vendidos4_df.columns = ['Producto', 'Cantidad']
productos_mas_vendidos4_df
# Out:
#                     Producto  Cantidad
# 0                   Cama box        62
# 1                 Cubertería        59
# 2    Dashboards con Power BI        56
# 3                  Cama king        56
# 4  Carrito de control remoto        55

# %%
plt.plot(productos_mas_vendidos4_df['Producto'], productos_mas_vendidos4_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos mas vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Cama box'),
#   Text(1, 0, 'Cubertería'),
#   Text(2, 0, 'Dashboards con Power BI'),
#   Text(3, 0, 'Cama king'),
#   Text(4, 0, 'Carrito de control remoto')])

# %%
## top 5 productos menos vendidos
productos_menos_vendidos4=tienda4['Producto'].value_counts().sort_values(ascending=True).head(5)
productos_menos_vendidos4
productos_menos_vendidos4_df = productos_menos_vendidos3.reset_index()
productos_menos_vendidos4_df.columns = ['Producto', 'Cantidad']
productos_menos_vendidos4_df
# Out:
#                   Producto  Cantidad
# 0  Bloques de construcción        35
# 1               Microondas        36
# 2             Set de vasos        36
# 3                  Mochila        36
# 4             Vaso térmico        38

# %%
plt.plot(productos_menos_vendidos4_df['Producto'], productos_menos_vendidos4_df['Cantidad'],marker='o',linestyle='--', color='blue')
plt.grid()
plt.title('Top 5 productos menos vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Bloques de construcción'),
#   Text(1, 0, 'Microondas'),
#   Text(2, 0, 'Set de vasos'),
#   Text(3, 0, 'Mochila'),
#   Text(4, 0, 'Vaso térmico')])

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_tienda1=tienda['Costo de envío'].mean()
costo_envio_tienda2=tienda2['Costo de envío'].mean()
costo_envio_tienda3=tienda3['Costo de envío'].mean()
costo_envio_tienda4=tienda4['Costo de envío'].mean()
print(f'Calificación Promedio de la tienda 1: S/ {costo_envio_tienda1:.2f}')
print(f'Calificación Promedio de la tienda 2: S/ {costo_envio_tienda2:.2f}')
print(f'Calificación Promedio de la tienda 3: S/ {costo_envio_tienda3:.2f}')
print(f'Calificación Promedio de la tienda 4: S/ {costo_envio_tienda4:.2f}')
# Out:
# Calificación Promedio de la tienda 1: S/ 26018.61
# Calificación Promedio de la tienda 2: S/ 25216.24
# Calificación Promedio de la tienda 3: S/ 24805.68
# Calificación Promedio de la tienda 4: S/ 23459.46

# %%
plt.pie([costo_envio_tienda1, costo_envio_tienda2,costo_envio_tienda3,costo_envio_tienda4],labels=tiendas, autopct='%1.1f%%', startangle=160)
plt.axis('equal') 
plt.title('Calificación promedio por tienda')
# Out:
# Text(0.5, 1.0, 'Calificación promedio por tienda')

# %% [markdown]
# # Informe Final
# Recomendación para el Sr. Juan sobre qué tienda vender
#
# ##### Introducción
#
# Con el objetivo de apoyar al Sr. Juan en su decisión de vender una de las tiendas de su cadena Alura Store para iniciar un nuevo emprendimiento, se ha realizado un análisis exhaustivo de las 4 tiendas disponibles. Este estudio incluye aspectos clave como ingresos totales, categorías de productos más vendidas, calificaciones promedio de clientes, productos más y menos vendidos y el costo de envío promedio. A partir de este análisis, se pretende identificar la tienda menos eficiente, fundamentando la recomendación con datos y visualizaciones generadas a lo largo del trabajo.
#
# ## Desarrollo
# ##### Ingresos Totales
#
# La tienda 1 presenta los mayores ingresos acumulados durante el periodo analizado, seguida por las tiendas 2 y 3. La tienda 4 se destaca negativamente, con una diferencia de más de $112.500.000 con respecto a la tienda 1. Esta tendencia decreciente podría estar relacionada con factores como la antigüedad del negocio, ubicación geográfica o nivel de consolidación.
#
# ##### Ventas por Categoría / Productos más y menos Vendidos
#
# Todas las tiendas comercializan las mismas categorías de productos. "Muebles" y "Electrónicos" destacan como las más vendidas en la mayoría de las tiendas. La tienda 4, aunque con menor facturación general, presenta un mejor comportamiento relativo en la categoría de "Juguetes". En cuanto a los productos específicos, los más vendidos tienden a ser muebles y dispositivos electrónicos, especialmente en las tiendas 1 y 3. Por el contrario, los productos menos vendidos están relacionados con libros e instrumentos musicales.
#
# ##### Calificaciones Promedio
#
# Las calificaciones promedio de las tiendas son similares, todas rondando un valor de 4 sobre 5. Sin embargo, la tienda 1, pese a ser la más exitosa en ventas, presenta la calificación más baja. Esto podría estar relacionado con el volumen de ventas y la dificultad de mantener altos estándares de servicio. La tienda 4 mantiene una calificación promedio similar a las demás, aunque con menor volumen de operaciones.
#
# ##### Coste de Envío Promedio
#
# Existe una correlación directa entre la cantidad de ventas y el costo de envío promedio. La tienda 1, con mayores ventas, también refleja el costo de envío promedio más alto. En contraste, la tienda 4 posee el costo de envío promedio más bajo, consistente con su menor actividad comercial.
#
# #### Conclusión
# Tras el análisis de todos los indicadores clave, se recomienda que el Sr. Juan venda la tienda 4. Esta tienda muestra un rendimiento inferior de forma consistente en los distintos indicadores:
#
# Es la que menos ingresos genera.
# Tiene menor participación en ventas por categoría.
# Su volumen de ventas y envíos es el más bajo.
# A pesar de mantener una calificación promedio similar a las demás tiendas, no destaca en ningún aspecto clave.
# Vender la tienda 4 permitirá al Sr. Juan enfocar sus recursos y energía en las tiendas con mejor rendimiento, y eventualmente reinvertir en estrategias que potencien la satisfacción del cliente y la eficiencia operativa. La información obtenida a través de este análisis ofrece una base sólida para tomar una decisión empresarial con respaldo cuantitativo.
